# %% [markdown]
# ## Crimean Tatar to English/Russian/Ukrainian parallel corpora

# %%
import pandas as pd

splits = {"crh_eng": "eng_crh.csv", "crh_rus": "rus_crh.csv", "crh_ukr": "ukr_crh.csv"}

# %% [markdown]
# ### latn

# %%
df = pd.read_csv("hf://datasets/QIRIM/crh-parallel-corpora/" + splits["crh_eng"])
df = df[(df["crh_Latn"].notna()) & (df["crh_Cyrl"].isna())][["crh_Latn", "target_lang"]]
df.to_csv("data/parallel_corpora/crh_Latn_eng.csv", index=False)
df.size
# Out:
# 24382

# %%
df = pd.read_csv("hf://datasets/QIRIM/crh-parallel-corpora/" + splits["crh_rus"])
df = df[(df["crh_Latn"].notna()) & (df["crh_Cyrl"].isna())][["crh_Latn", "target_lang"]]
df.to_csv("data/parallel_corpora/crh_Latn_rus.csv", index=False)
df.size
# Out:
# 38618

# %%
df = pd.read_csv("hf://datasets/QIRIM/crh-parallel-corpora/" + splits["crh_ukr"])
df = df[(df["crh_Latn"].notna()) & (df["crh_Cyrl"].isna())][["crh_Latn", "target_lang"]]
df.to_csv("data/parallel_corpora/crh_Latn_ukr.csv", index=False)
df.size
# Out:
# 24900

# %% [markdown]
# ### cyrl

# %%
df = pd.read_csv("hf://datasets/QIRIM/crh-parallel-corpora/" + splits["crh_eng"])
df = df[(df["crh_Latn"].isna()) & (df["crh_Cyrl"].notna())][["crh_Cyrl", "target_lang"]]
df.to_csv("data/parallel_corpora/crh_Cyrl_eng.csv", index=False)
df.size
# Out:
# 2642

# %%
df = pd.read_csv("hf://datasets/QIRIM/crh-parallel-corpora/" + splits["crh_rus"])
df = df[(df["crh_Latn"].isna()) & (df["crh_Cyrl"].notna())][["crh_Cyrl", "target_lang"]]
df.to_csv("data/parallel_corpora/crh_Cyrl_rus.csv", index=False)
df.size
# Out:
# 89434

# %%
df = pd.read_csv("hf://datasets/QIRIM/crh-parallel-corpora/" + splits["crh_ukr"])
df = df[(df["crh_Latn"].isna()) & (df["crh_Cyrl"].notna())][["crh_Cyrl", "target_lang"]]
df.to_csv("data/parallel_corpora/crh_Cyrl_ukr.csv", index=False)
df.size
# Out:
# 38780

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("ai-forever/mGPT-1.3B-tatar")
model = GPT2LMHeadModel.from_pretrained("ai-forever/mGPT-1.3B-tatar").cuda()

text = "Александр Сергеевич Пушкин родился в "
input_ids = tokenizer.encode(text, return_tensors="pt").cuda()
out = model.generate(
        input_ids, 
        min_length=100, 
        max_length=100, 
        eos_token_id=5, 
        top_k=10,
        top_p=0.0,
        no_repeat_ngram_size=5
)
generated_text = list(map(tokenizer.decode, out))[0]
print(generated_text)
model
# Out:
# The following generation flags are not valid and may be ignored: ['top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Александр Сергеевич Пушкин родился в Әстерхан шәһәрендә, әтисе — Александр Сергеевич Пушкинның әтисенең өченче баласы. Атасының үлеменнән соң, әнисе — Ольга Павловна, ә әтисеннән соравы буен
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(100000, 2048)
#     (wpe): Embedding(2048, 2048)
#     (drop): Dropout(p=0.1, inplace=False)
# ...
